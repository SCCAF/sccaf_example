# %% [markdown]
# # Zeisel, A. et al. Mouse Cortex

# %%
# %pylab inline

import warnings
warnings.filterwarnings("ignore")
from SCCAF import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ad = sc.read("../write/Zeisel_reg.h5")

# %%
sc.tl.louvain(ad, resolution=1, key_added = 'louvain_r1')

# %%
figsize(5,5)
sc.pl.tsne(ad, color=['cell','louvain_r1'], frameon=False)

# %% [markdown]
# ## SCCAF assessment
# > use self-projection to test the global accuracy of a clustering (the human expert clustering).
# We find the discrimination between the human annotated cell types is very clear and the accuracy is up to 96%. It shows an almost-perfect clustering.

# %%
figsize(8,4)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(ad.X, ad.obs['cell'],n=100)
aucs = plot_roc(y_prob, y_test, clf, cvsm=cvsm, acc=acc)
plt.show()
# Out:
# Mean CV accuracy: 0.9569
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.9550

# %% [markdown]
# ## SCCAF recover
# When the data annotation is unknown and we aim to identify the best clustering solution.
# We may start with a `over-clustering` and optimize the clustering by merging the clusters that cannot be discriminated by a machine learning model.
# (Here we use `logistic regression`, which uses a linear model, for the machine learning.) And we also constrain the optimization with a `under-clustering`.
#
# In this example, we start with louvain clustering resolution 1.0 (`louvain_r1`).
#
# We assign the optimization name (the `prefix` parameter) as `L1`, and the initial state of the optimization is named as `L1_Round0` kept in the `anndata.obs` slot.
# Each Round of the optimization will increase the index, from `L1_Round1`, `L1_Round2` to `L1_Round10` ....

# %%
# %%time
figsize(4,4)
SCCAF_optimize_all(start='louvain_r1',min_acc=0.96, ad=ad, use='pca', basis ='tsne',c_iter=5)
# Out:
# R1norm_cutoff: 0.500000
# R2norm_cutoff: 0.050000
# Accuracy: 0.000000
# ======================
# Round1 ...
# Mean CV accuracy: 0.8965
# Accuracy on the training set: 0.9716
# Accuracy on the hold-out set: 0.9122
# Accuracy on the training set: 0.9689
# Accuracy on the hold-out set: 0.9096
# Accuracy on the training set: 0.9753
# Accuracy on the hold-out set: 0.9143
# Accuracy on the training set: 0.9670
# Accuracy on the hold-out set: 0.9106
# Accuracy on the training set: 0.9799
# Accuracy on the hold-out set: 0.9012
# Max R1mat: 0.166667
# Max R2mat: 0.009060
# min_acc: 0.901202
# IGRAPH U-W- 14 0 --
# + attr: weight (e)
# Converge SCCAF_optimize no. cluster!
# m1: 0.166667
# m2: 0.009060
# Accuracy: 0.901202
# R1norm_cutoff: 0.156667
# R2norm_cutoff: 0.008060
# Accuracy: 0.901202
# ======================
# Round1 ...
# Mean CV accuracy: 0.9084
# Accuracy on the training set: 0.9707
# Accuracy on the hold-out set: 0.9022
# Accuracy on the training set: 0.9661
# Accuracy on the hold-out set: 0.9117
# Accuracy on the training set: 0.9652
# Accuracy on the hold-out set: 0.9080
# Accuracy on the training set: 0.9725
# Accuracy on the hold-out set: 0.9075
# Accuracy on the training set: 0.9661
# Accuracy on the hold-out set: 0.9054
# Max R1mat: 0.225352
# Max R2mat: 0.011973
# min_acc: 0.902248
# ... storing 'L1_Round0_self-projection' as categorical
# ... storing 'L1_Round1' as categorical
# ... storing 'L1_Round2_self-projection' as categorical
# IGRAPH U-W- 14 2 --
# + attr: weight (e)
# + edges:
# 0--7 0--7
# Round2 ...
# Mean CV accuracy: 0.9006
# Accuracy on the training set: 0.9732
# Accuracy on the hold-out set: 0.9160
# Accuracy on the training set: 0.9791
# Accuracy on the hold-out set: 0.9180
# Accuracy on the training set: 0.9761
# Accuracy on the hold-out set: 0.9090
# Accuracy on the training set: 0.9702
# Accuracy on the hold-out set: 0.9275
# Accuracy on the training set: 0.9801
# Accuracy on the hold-out set: 0.9130
# Max R1mat: 0.181818
# Max R2mat: 0.010259
# min_acc: 0.908954
# ... storing 'L1_Round1_self-projection' as categorical
# ... storing 'L1_Round2' as categorical
# IGRAPH U-W- 13 6 --
# + attr: weight (e)
# + edges:
# 0--8 0--12 2--3 2--3 0--8 0--12
# Round3 ...
# Mean CV accuracy: 0.9256
# Accuracy on the training set: 0.9805
# Accuracy on the hold-out set: 0.9327
# Accuracy on the training set: 0.9866
# Accuracy on the hold-out set: 0.9364
# Accuracy on the training set: 0.9841
# Accuracy on the hold-out set: 0.9254
# Accuracy on the training set: 0.9720
# Accuracy on the hold-out set: 0.9428
# Accuracy on the training set: 0.9866
# Accuracy on the hold-out set: 0.9396
# Max R1mat: 0.377049
# Max R2mat: 0.013139
# min_acc: 0.925400
# ... storing 'L1_Round2_self-projection' as categorical
# ... storing 'L1_Round3' as categorical
# IGRAPH U-W- 10 2 --
# + attr: weight (e)
# + edges:
# 1--6 1--6
# Round4 ...
# Mean CV accuracy: 0.9490
# Accuracy on the training set: 0.9906
# Accuracy on the hold-out set: 0.9482
# Accuracy on the training set: 0.9893
# Accuracy on the hold-out set: 0.9402
# Accuracy on the training set: 0.9946
# Accuracy on the hold-out set: 0.9526
# Accuracy on the training set: 0.9866
# Accuracy on the hold-out set: 0.9500
# Accuracy on the training set: 0.9893
# Accuracy on the hold-out set: 0.9314
# Max R1mat: 0.317460
# Max R2mat: 0.010261
# min_acc: 0.931386
# ... storing 'L1_Round3_self-projection' as categorical
# ... storing 'L1_Round4' as categorical
# IGRAPH U-W- 9 4 --
# + attr: weight (e)
# + edges:
# 0--6 1--8 0--6 1--8
# Round5 ...
# Mean CV accuracy: 0.9641
# Accuracy on the training set: 0.9922
# Accuracy on the hold-out set: 0.9700
# Accuracy on the training set: 0.9969
# Accuracy on the hold-out set: 0.9729
# Accuracy on the training set: 0.9969
# Accuracy on the hold-out set: 0.9738
# Accuracy on the training set: 0.9984
# Accuracy on the hold-out set: 0.9700
# Accuracy on the training set: 0.9984
# Accuracy on the hold-out set: 0.9657
# Max R1mat: 0.029703
# Max R2mat: 0.001747
# Converge SCCAF_optimize min_acc!
# m1: 0.029703
# m2: 0.001747
# Accuracy: 0.965722
# CPU times: user 37.8 s, sys: 1.07 s, total: 38.9 s
# Wall time: 15.1 s

# %%
ad.write("../write/Zeisel_reg.h5")

# %%
sc.pl.tsne(ad, color=['L1_result','cell',],frameon=False, title=['SCCAF','Human Annotation'])
# Out:
# ... storing 'L1_Round4_self-projection' as categorical

# %% [markdown]
# ## SCCAF recover with constraints
#
# In this example, we start with louvain clustering resolution 1.0 (`louvain_r1`) and constrain the optimization with louvain clustering resolution 0.2 (`louvain_r0.2`).

# %%
sc.tl.louvain(ad, resolution=0.1, key_added='louvain_r0.1')

# %%
figsize(4,4)
sc.pl.tsne(ad, color=['louvain_r0.1'])

# %%
# %%time
SCCAF_optimize_all(start='louvain_r1',min_acc=0.965, ad=ad, use='pca', basis ='tsne',low_res='louvain_r0.1', prefix='L2')
# Out:
# R1norm_cutoff: 0.500000
# R2norm_cutoff: 0.050000
# Accuracy: 0.000000
# ======================
# Round1 ...
# Mean CV accuracy: 0.8993
# Accuracy on the training set: 0.9753
# Accuracy on the hold-out set: 0.9043
# Accuracy on the training set: 0.9707
# Accuracy on the hold-out set: 0.9022
# Accuracy on the training set: 0.9780
# Accuracy on the hold-out set: 0.9064
# Max R1mat: 0.186441
# Max R2mat: 0.014013
# min_acc: 0.902248
# IGRAPH U-W- 14 0 --
# + attr: weight (e)
# Converge SCCAF_optimize no. cluster!
# m1: 0.186441
# m2: 0.014013
# Accuracy: 0.902248
# R1norm_cutoff: 0.176441
# R2norm_cutoff: 0.013013
# Accuracy: 0.902248
# ======================
# Round1 ...
# Mean CV accuracy: 0.8864
# Accuracy on the training set: 0.9707
# Accuracy on the hold-out set: 0.9054
# Accuracy on the training set: 0.9643
# Accuracy on the hold-out set: 0.9049
# Accuracy on the training set: 0.9762
# Accuracy on the hold-out set: 0.9164
# Max R1mat: 0.233766
# Max R2mat: 0.013438
# min_acc: 0.904861
# ... storing 'L2_Round0_self-projection' as categorical
# ... storing 'L2_Round1' as categorical
# IGRAPH U-W- 14 2 --
# + attr: weight (e)
# + edges:
# 0--7 0--7
# Round2 ...
# Mean CV accuracy: 0.9144
# Accuracy on the training set: 0.9742
# Accuracy on the hold-out set: 0.9210
# Accuracy on the training set: 0.9742
# Accuracy on the hold-out set: 0.9115
# Accuracy on the training set: 0.9761
# Accuracy on the hold-out set: 0.9185
# Max R1mat: 0.250000
# Max R2mat: 0.015873
# min_acc: 0.911456
# ... storing 'L2_Round1_self-projection' as categorical
# ... storing 'L2_Round2' as categorical
# IGRAPH U-W- 13 2 --
# + attr: weight (e)
# + edges:
# 0--12 0--12
# Round3 ...
# Mean CV accuracy: 0.9102
# Accuracy on the training set: 0.9737
# Accuracy on the hold-out set: 0.9226
# Accuracy on the training set: 0.9737
# Accuracy on the hold-out set: 0.9241
# Accuracy on the training set: 0.9768
# Accuracy on the hold-out set: 0.9191
# Max R1mat: 0.205882
# Max R2mat: 0.014092
# min_acc: 0.919107
# ... storing 'L2_Round2_self-projection' as categorical
# ... storing 'L2_Round3' as categorical
# IGRAPH U-W- 12 2 --
# + attr: weight (e)
# + edges:
# 0--8 0--8
# Round4 ...
# Mean CV accuracy: 0.9250
# Accuracy on the training set: 0.9707
# Accuracy on the hold-out set: 0.9146
# Accuracy on the training set: 0.9707
# Accuracy on the hold-out set: 0.9242
# Accuracy on the training set: 0.9837
# Accuracy on the hold-out set: 0.9271
# Max R1mat: 0.193548
# Max R2mat: 0.011646
# min_acc: 0.914628
# ... storing 'L2_Round3_self-projection' as categorical
# ... storing 'L2_Round4' as categorical
# IGRAPH U-W- 11 4 --
# + attr: weight (e)
# + edges:
# 0--10 2--7 2--7 0--10
# Round5 ...
# Mean CV accuracy: 0.9348
# Accuracy on the training set: 0.9901
# Accuracy on the hold-out set: 0.9416
# Accuracy on the training set: 0.9815
# Accuracy on the hold-out set: 0.9476
# Accuracy on the training set: 0.9828
# Accuracy on the hold-out set: 0.9380
# Max R1mat: 0.121212
# Max R2mat: 0.013333
# min_acc: 0.937984
# IGRAPH U-W- 9 0 --
# + attr: weight (e)
# Converge SCCAF_optimize no. cluster!
# m1: 0.121212
# m2: 0.013333
# Accuracy: 0.937984
# start_iter: 4
# R1norm_cutoff: 0.111212
# R2norm_cutoff: 0.012333
# Accuracy: 0.937984
# ======================
# Round5 ...
# Mean CV accuracy: 0.9384
# Accuracy on the training set: 0.9889
# Accuracy on the hold-out set: 0.9389
# Accuracy on the training set: 0.9828
# Accuracy on the hold-out set: 0.9457
# Accuracy on the training set: 0.9803
# Accuracy on the hold-out set: 0.9453
# Max R1mat: 0.160714
# Max R2mat: 0.015130
# min_acc: 0.938896
# ... storing 'L2_Round4_self-projection' as categorical
# ... storing 'L2_Round5' as categorical
# IGRAPH U-W- 9 4 --
# + attr: weight (e)
# + edges:
# 0--3 0--7 0--3 0--7
# Round6 ...
# Mean CV accuracy: 0.9657
# Accuracy on the training set: 0.9953
# Accuracy on the hold-out set: 0.9721
# Accuracy on the training set: 0.9984
# Accuracy on the hold-out set: 0.9746
# Accuracy on the training set: 0.9984
# Accuracy on the hold-out set: 0.9674
# Max R1mat: 0.048544
# Max R2mat: 0.003020
# Converge SCCAF_optimize min_acc!
# m1: 0.048544
# m2: 0.003020
# Accuracy: 0.967414
# CPU times: user 42.4 s, sys: 1.46 s, total: 43.8 s
# Wall time: 18.2 s

# %%
sc.pl.tsne(ad, color=['L2_result','cell',],frameon=False, title=['SCCAF','Human Annotation'])
# Out:
# ... storing 'L2_Round5_self-projection' as categorical

# %%
ad.write("../write/Zeisel_reg.h5")

# %% [markdown]
# # End
